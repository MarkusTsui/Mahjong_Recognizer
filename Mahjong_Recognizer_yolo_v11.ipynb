# %%
# !nvidia-smi
# Out:
# Tue Dec 31 12:12:22 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 566.36                 Driver Version: 566.36         CUDA Version: 12.7     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4070 ...  WDDM  |   00000000:01:00.0  On |                  N/A |
# | 42%   34C    P0             26W /  220W |    1168MiB /  12282MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics

# %%
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.56  Python-3.9.21 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 4070 SUPER, 12282MiB)
# Setup complete  (12 CPUs, 31.9 GB RAM, 920.5/952.8 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import Image, display

# %%
# !pip install roboflow --user

from roboflow import Roboflow
rf = Roboflow(api_key="qSH0zfGXmauRndaFmqZZ")
project = rf.workspace("mahjong-rep95").project("mahjong-ma2nf")
version = project.version(5)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
dataset.location
# Out:
# 'C:\\Users\\blackdog\\GeorgeBrown\\Yolov11\\Mahjong\\mahjong-5'

# %%
# !yolo task=detect mode=train data={dataset.location}/data.yaml model ="yolo11s.pt" epochs=50 imgsz=640 device=0
# Out:
# Ultralytics 8.3.56 🚀 Python-3.9.21 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 4070 SUPER, 12282MiB)
# ...

# %%
# !yolo task=detect mode=train data={dataset.location}/data.yaml model ="yolo11m.pt" epochs=100 imgsz=640

# %%
display(Image("/GeorgeBrown/Yolov11/Mahjong/runs/detect/train2/confusion_matrix.png"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\envs\yolo-gpu\lib\site-packages\IPython\core\display.py:1045, in Image._data_and_metadata(self, always_both)
#    1044 try:
# -> 1045     b64_data = b2a_base64(self.data, newline=False).decode("ascii")
#    1046 except TypeError as e:
#
# TypeError: a bytes-like object is required, not 'str'
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# File ~\anaconda3\envs\yolo-gpu\lib\site-packages\IPython\core\formatters.py:974, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#     971     method = get_real_method(obj, self.print_method)
#     973     if method is not None:
# --> 974         return method(include=include, exclude=exclude)
#     975     return None
#     976 else:
#
# ...
